# %%
import time

def send_message():
    message_count = 0
    while (message_count<10):
        message_count += 1
        print(f"Call me {message_count} sent.")
        time.sleep(1)  # Wait for 1 second

if __name__ == "__main__":
    send_message()
# Out:
# Call me 1 sent.
# Call me 2 sent.
# Call me 3 sent.
# Call me 4 sent.
# Call me 5 sent.
# Call me 6 sent.
# Call me 7 sent.
# Call me 8 sent.
# Call me 9 sent.
# Call me 10 sent.

# %%
pip install pywhatkit
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Obtaining dependency information for pywhatkit from https://files.pythonhosted.org/packages/8c/58/e06d722ddaf7100765c5d0a34caf8d9fe92202bfabe632a9dea572312901/pywhatkit-5.4-py3-none-any.whl.metadata
# ...
#   Using cached PyAutoGUI-0.9.54.tar.gz (61 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached wikipedia-1.4.0.tar.gz (27 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
import pywhatkit as kit

# Define the phone number (include the country code) and message
phone_number = "+923121561084"  # Replace with the actual phone number
message = "Hello! This is a test message."

# Send the message
kit.sendwhatmsg(phone_number, message, 15, 0)  # Sends the message at 15:00 (3:00 PM)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import pywhatkit as kit
#       3 # Define the phone number (include the country code) and message
#       4 phone_number = "+923121561084"  # Replace with the actual phone number
#
# ModuleNotFoundError: No module named 'pywhatkit'

# %%
pip install selenium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Obtaining dependency information for selenium from https://files.pythonhosted.org/packages/c9/33/b9da8be5b122b8c3c82c35f515ba0a84a9af3ba9629ae9fd5bbba820d592/selenium-4.23.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for trio~=0.17 from https://files.pythonhosted.org/packages/77/34/461280cc615614a9e434c6e23373371a2436f71d045303cadabb1d775eba/trio-0.26.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for trio-websocket~=0.9 from https://files.pythonhosted.org/packages/48/be/a9ae5f50cad5b6f85bd2574c2c923730098530096e170c1ce7452394d7aa/trio_websocket-0.11.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for websocket-client~=1.8 from https://files.pythonhosted.org/packages/5a/84/44687a29792a70e111c5c477230a72c4b957d88d16141199bf9acb7537a3/websocket_client-1.8.0-py3-none-any.whl.metadata
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
import time

# Set up Chrome options
chrome_options = Options()
chrome_options.add_argument("--user-data-dir=/path/to/your/chrome/profile")  # Optional: use your Chrome profile for faster login

# Path to your ChromeDriver
service = Service('/path/to/chromedriver')

# Start Chrome browser
driver = webdriver.Chrome(service=service, options=chrome_options)

try:
    # Open WhatsApp Web
    driver.get('https://web.whatsapp.com/')
    time.sleep(15)  # Wait for the user to scan the QR code

    # Find the search box and enter the contact name
    search_box = driver.find_element_by_xpath('//div[@contenteditable="true"][@data-tab="3"]')
    search_box.click()
    search_box.send_keys('Mimi🌸')  # Replace with the contact name
    time.sleep(2)  # Wait for search results to load

    # Select the contact
    contact = driver.find_element_by_xpath('//span[@title="Mini🌸"]')  # Replace with the contact name
    contact.click()
    time.sleep(2)

    # Find the message input box and send the message
    message_box = driver.find_element_by_xpath('//div[@contenteditable="true"][@data-tab="1"]')
    message_box.click()
    message_box.send_keys('Hello! This is a test message.')  # Replace with your message
    message_box.send_keys(Keys.RETURN)

finally:
    # Close the browser after sending the message
    time.sleep(5)
    driver.quit()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\selenium\webdriver\common\driver_finder.py:64, in DriverFinder._binary_paths(self)
#      63 if not Path(path).is_file():
# ---> 64     raise ValueError(f"The path is not a valid file: {path}")
#      65 self._paths["driver_path"] = path
#
# ValueError: The path is not a valid file: /path/to/chromedriver
#
# The above exception was the direct cause of the following exception:
#
# NoSuchDriverException                     Traceback (most recent call last)
# Cell In[7], line 15
#      12 service = Service('/path/to/chromedriver')
#      14 # Start Chrome browser
# ---> 15 driver = webdriver.Chrome(service=service, options=chrome_options)
#      17 try:
#      18     # Open WhatsApp Web
#      19     driver.get('https://web.whatsapp.com/')
#
# ...
